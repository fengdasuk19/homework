# %% [markdown]
# ##  基本模块导入与构建

# %%
# import modules

import os
import copy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch.nn import functional as F
from torch.autograd import Variable

import torchvision
from torchvision import utils as vutil

from IPython.display import display
# %matplotlib inline

# %%
# define some common-used constant variables

use_cuda = torch.cuda.is_available()

# %%
# prepare dataset

path = {
    'datasets': os.path.join(os.getcwd(), 'datasets'), 
    'models': os.path.join(os.getcwd(), 'models'),
    'outputs_aux': os.path.join(os.getcwd(), 'outputs_aux')
}

for k,path_val in path.items():
    if not os.path.isdir(path_val):
        os.mkdir(path_val)

transform_sets = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor()
])

params = {
    'datasets': {
        'root': path['datasets'], 
        'download': True,
        'transform': transform_sets
    }
}

data = {
    'train': torchvision.datasets.MNIST(train=True, **params['datasets']), 
    'test': torchvision.datasets.MNIST(train=False, **params['datasets']), 
}
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %%
# set dataloader

batch_size = 100
n_class = 11
dataloader = {}

## dataloader-train

dataloader['train'] = torch.utils.data.DataLoader(dataset=data['train'], batch_size=batch_size, shuffle=True)

## dataloader-valid & dataloader-test

### auxiliary components

indicies = {
    'valid': range(len(data['test'])//2),
    'test': range(len(data['test'])//2, len(data['test']))
}
sampler = {
    'valid': torch.utils.data.sampler.SubsetRandomSampler(indices=indicies['valid']),
    'test': torch.utils.data.sampler.SubsetRandomSampler(indices=indicies['test'])
}

### dataloder definition

dataloader['valid'] = torch.utils.data.DataLoader(dataset=data['test'], batch_size=batch_size, 
                                                  sampler=sampler['valid'])

dataloader['test'] = torch.utils.data.DataLoader(dataset=data['test'], batch_size=batch_size, 
                                                  sampler=sampler['test'])

# %% [markdown]
# ## 查看三个迭代器的信息

# %%
def vis_dist_dataloader(cls):
    count = {i:0 for i in range(n_class)}
    for i, data in enumerate(dataloader[cls]):
        xs, ys = data
        for y in ys:
            count[y] += 1
            
    count = [count[i] for i in range(n_class)]
    display(pd.DataFrame(data=count))
    plt.bar(left=np.arange(n_class), height=count)
    plt.xlabel('digit_class')
    plt.ylabel('count_total_samples')
    plt.title('simple stat: data[{}]'.format(cls))
    filename_base = 'stat-{}'.format(cls)
    filename_full = os.path.join(path['outputs_aux'], filename_base)
    plt.savefig(filename_full)

# %%
vis_dist_dataloader('train')
# Out:
#        0
# 0   5923
# 1   6742
# 2   5958
# 3   6131
# 4   5842
# 5   5421
# 6   5918
# 7   6265
# 8   5851
# 9   5949
# 10     0

# %%
vis_dist_dataloader('valid')
# Out:
#       0
# 0   460
# 1   571
# 2   530
# 3   500
# 4   500
# 5   456
# 6   462
# 7   512
# 8   489
# 9   520
# 10    0

# %%
vis_dist_dataloader('test')
# Out:
#       0
# 0   520
# 1   564
# 2   502
# 3   510
# 4   482
# 5   436
# 6   496
# 7   516
# 8   485
# 9   489
# 10    0

# %% [markdown]
# ## 实验设计

# %% [markdown]
# 【问题 1】示例：**图像** -> **图像**
#
# 【问题 2】目标：**文本** -> **图像**
#
# 那是否有什么方式可以把【问题 2】转化为【问题 1】，或者结合【问题 1】的解法？

# %% [markdown]
# 首先回顾一下【问题 1】的 GAN 的代码过程：
#
# 1. 给出来自**原始数据**的真实图片，手动标记全为真（1）；喂给判别器 D，计算误差 1 `error_real`
# 2. 给出来自**生成器 G**的生成图片，手动标记全为假（0）；喂给判别器 D，计算误差 2 `error_fake`
# 3. 反向传播「误差 1 + 误差 2」（`error_D = error_real + error_fake`），用来**训练判别器 D**
# 4. 对生成图片，重新手动标记全为真（1）；喂给判别器 D，计算误差 3 `error_G`
# 5. 使用误差 3 `error_G` 来**训练生成器 G**

# %% [markdown]
# ### 方案 1: GAN(11 分类)

# %% [markdown]
# 这种方案思路是：把原始判断「真/假」的**二分类**问题，转化为判断「真0/真1/…/真9/假图」的**十一分类**问题
#
# 那么只要更改标记即可：
#
# + 对真实图片，标记使用图片对应标签 `label`
# + 对假图，在**训练 D 前**，喂给 D 时仍然标记为 0
# + 对假图，在**训练 G 前**，喂给 D 的标签使用图片对应标签 `label`
#
# **但这样的思想似乎与 GAN 无监督的框架又有所违背，又成了有监督学习了**

# %% [markdown]
# ### 方案 2: GAN(2 分类) + CNN(10 分类)

# %% [markdown]
# 这种方案的思路是：在 GAN 的判别器判别假图为真后，将假图输入给另一个预训练 CNN（如 VGG）来判断这个假图的数字，然后在 CNN 固定权重的前提下用 CNN 输出结果反传梯度，以便修正生成器网络 G。
#
# > 可能这种方式更适合于 GAN 的无监督架构

# %% [markdown]
# ## 实验执行

# %%
input_dim = n_class
num_features = 64
num_channels = 1

# %%
# definition for Generator

class ModelG(nn.Module):
    
    def __init__(self):
        super(ModelG, self).__init__()
        self.deconv00 = nn.ConvTranspose2d(in_channels=input_dim, out_channels=num_features*2, 
                                           kernel_size=5, stride=2, padding=0) #, bias=False)
        self.deconv01 = nn.ConvTranspose2d(in_channels=num_features*2, out_channels=num_features, 
                                           kernel_size=5, stride=2, padding=0) #, bias=False)
        self.deconv02 = nn.ConvTranspose2d(in_channels=num_features, out_channels=num_channels, 
                                           kernel_size=4, stride=2, padding=0) #, bias=False)
        self.bn00 = nn.BatchNorm2d(num_features=num_features*2)
        self.bn01 = nn.BatchNorm2d(num_features=num_features)
        ######DIFFERENT from example code######
        ## add one layer for one label input ##
        ## remove `bias=False`               ##
        #######################################
    
    def forward(self, x, training=True):
        x = self.bn00(self.deconv00(x))
#         print('deconv0: ', x.data.size())
        x = F.leaky_relu(x, negative_slope=.2)
        x = self.bn01(self.deconv01(x))
#         print('deconv1: ', x.data.size())
        x = F.leaky_relu(x, negative_slope=.2)
        x = self.deconv02(x)
#         print('deconv2: ', x.data.size())
        output = F.tanh(x)
        
        return output

# %%
# definition for Discriminator

class ModelD(nn.Module):
    
    def __init__(self):
        super(ModelD, self).__init__()
        self.conv00 = nn.Conv2d(in_channels=num_channels, out_channels=num_features, 
                                kernel_size=5, stride=2, padding=0) #, bias=False)
        self.bn00 = nn.BatchNorm2d(num_features=num_features)
        self.conv01 = nn.Conv2d(in_channels=num_features, out_channels=num_features*2, 
                                kernel_size=5, stride=2, padding=0) #, bias=False)
        self.bn01 = nn.BatchNorm2d(num_features=num_features*2)
        self.fc00 = nn.Linear(in_features=(num_features*2 * 4 * 4), out_features=num_features)
        self.fc01 = nn.Linear(in_features=num_features, out_features=n_class)
        ######DIFFERENT from example code######
        ## remove `bias=False`               ##
        #######################################
    
    def forward(self, x, training=True):
        x = self.bn00(F.leaky_relu(self.conv00(x), negative_slope=.2))
        x = self.bn01(F.leaky_relu(self.conv01(x), negative_slope=.2))
        x = x.view(-1, num_features*2 * 4 * 4)
        x = F.leaky_relu(self.fc00(x), negative_slope=.2)
        x = self.fc01(x)
        output = F.log_softmax(x)
        
        return output

# %%
def weight_init(m):
    if isinstance(m, ModelG) or isinstance(m, ModelD):
        return
    try:
        class_name = m.__class__.name
    except:
        class_name = m.__str__()
    if class_name.find('conv') != -1:
        m.weight.data.normal_(0, 0.02)
    if class_name.find('norm') != -1:
        m.weight.data.normal_(1.0, 0.02)

# %%
image_size = 28

def make_show(img):
    # 将张量变成可以显示的图像
    img = img.data.expand(batch_size, 3, image_size, image_size)
    return img

# %%
def imshow(inp, title=None):
    # 在屏幕上绘制图像
    """Imshow for Tensor."""
    if inp.size()[0] > 1:
        inp = inp.numpy().transpose((1, 2, 0))
    else:
        inp = inp[0].numpy()
    mvalue = np.amin(inp)
    maxvalue = np.amax(inp)
    if maxvalue > mvalue:
        inp = (inp - mvalue)/(maxvalue - mvalue)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# %%
print('you can start now')
# Out:
# you can start now

# %% [markdown]
# ### 方案 1: GAN(11 分类)

# %%
def gen_noise(ys, batch_size=batch_size, input_dim=input_dim):
    noise = np.random.randn(batch_size, input_dim, 1, 1)

    new_noise = []
    for i_b, y in enumerate(ys):
        base = noise[i_b].reshape(-1)
        item = np.zeros(input_dim)
        whichone = y.cpu().data.numpy()[0] if use_cuda else y.data.numpy()[0]
        item[whichone] = 10
        full = (base + item).reshape(input_dim, 1, 1)
        new_noise.append([full])
        
    noise = np.concatenate(new_noise).astype(np.float32)
        
    return torch.from_numpy(noise)

# %%
# init: netG(Generator)

netG = ModelG().cuda() if use_cuda else ModelG()
netG.apply(weight_init)
optG = torch.optim.Adam(netG.parameters(), lr=0.000002,betas=(0.5,0.999))#, lr=0.0002,betas=(0.5,0.999)) # DIFFERENT from example code

# init: netD(Discriminator)

netD = ModelD().cuda() if use_cuda else ModelD()
netD.apply(weight_init)
optD = torch.optim.SGD(netD.parameters(), lr=0.0002)#, lr=0.0002,betas=(0.5,0.999))

# inputs...

# noise = Variable(torch.FloatTensor(batch_size, 1, 1, 1))
# fixed_noise = torch.from_numpy(np.random.choice(n_class-1, batch_size))
# fixed_noise = fixed_noise.view(batch_size, 1, 1, 1)

# noise, fixed_noise = (noise.cuda(), fixed_noise.cuda()) if use_cuda else (noise, fixed_noise)    
    

# loss...

criterion = nn.CrossEntropyLoss()
error_G = None
num_epochs = 100
results = []

threshold = 0.5 # DIFFERENT from example code

for epoch in range(num_epochs):
    
    for batch_idx, (xs_raw, ys_raw) in enumerate(dataloader['train']):
        
        # 1. REAL pic
        optD.zero_grad()
        
        ## use cuda?
        label_shape = ys_raw.size()
        label_type = torch.cuda.LongTensor if use_cuda else torch.LongTensor
        xs, ys = (xs_raw.cuda(), ys_raw.cuda()) if use_cuda else (xs_raw, ys_raw)
        
        ## pack in Variable
        xs, ys = Variable(xs), Variable(ys)
        
        netD.train() # set training state
        output = netD(xs)
        error_real = criterion(output, ys)
        error_real.backward() # BP 01 -> netD
        
        # 2. Generate pic
#         noise = torch.FloatTensor(batch_size, input_dim, 1, 1)
#         noise = torch.normal(torch.zeros(label_shape), torch.ones(label_shape))
#         noise = (noise + ys.type(torch.FloatTensor).data) / 10.0
#         noise = Variable(noise)
#         noise = noise.unsqueeze(1).expand(noise.size()[0], input_dim)
#         noise.data.resize_(noise.data.size()[0], input_dim, 1, 1)
        noise = Variable(gen_noise(ys))
        noise.data = noise.data.cuda() if use_cuda else noise.data #gpu transform
        fake_pic = netG(noise).detach()
        output2 = netD(fake_pic)
#         label = Variable(torch.zeros(label_shape).type(label_type))
        label = Variable(torch.from_numpy(np.array([n_class-1] * label_shape[0])).type(label_type))
        error_fake = criterion(output2, label)
        error_fake.backward()
        error_D = error_real + error_fake
        optD.step() # start to optimize: Discriminator
        
        # train Generator alone:
#         error_G = Variable(torch.zeros(1))
        if (error_G is None) or (np.random.rand() < threshold):
            optG.zero_grad()
            netG.train()
#             noise = torch.normal(torch.zeros(label_shape), torch.ones(label_shape))
#             noise = (noise + ys.type(torch.FloatTensor).data) / 10.0
#             noise = Variable(noise)
#             noise = noise.unsqueeze(1).expand(noise.size()[0], input_dim)
#             noise.data.resize_(noise.data.size()[0], input_dim, 1, 1)
            noise = Variable(gen_noise(ys))
            noise.data = noise.data.cuda() if use_cuda else noise.data #gpu transform
            fake_pic = netG(noise)
            output3 = netD(fake_pic)
#             if use_cuda:
#                 m_v,m_i = torch.max(output3.cpu(), 1)
#             else:
#                 m_v,m_i = torch.max(output3, 1)
#             if m_i.numpy() < (n_class-1):
#                 print('good')            
            error_G = criterion(output3, ys.type(label_type))
            error_G.backward()
            optG.step() # start to optimize: Generator
        
        error_D, error_G = (error_D.cpu(), error_G.cpu()) if use_cuda else (error_D, error_G)
        results.append([float(error_D.data.numpy()), float(error_G.data.numpy())])
        
        if batch_idx % 100 == 0:
#             print('output:', output.cpu().data if use_cuda else output.data)
#             print('output2:', output2.cpu().data if use_cuda else output2.data)
#             print('error_real: {} \t error_fake: {}'.format(error_real, error_fake))
            print ('第{}周期，第{}/{}撮, 分类器Loss:{:.2f}, 生成器Loss:{:.2f}'.format(
                epoch,batch_idx,len(dataloader['train']), error_D.data[0], error_G.data[0]))
            
    # Generate some fake pics and evaluate
    netG.eval()
    fixed_noise = torch.from_numpy(np.random.choice(n_class-1, batch_size))
    fixed_noise = fixed_noise.type(torch.FloatTensor)
    fixed_noise = fixed_noise.unsqueeze(1).expand(fixed_noise.size()[0], input_dim)
    fixed_noise = Variable(fixed_noise)
    fixed_noise.data.resize_(fixed_noise.data.size()[0], input_dim, 1, 1)
    fixed_noise.data = fixed_noise.data.cuda() if use_cuda else fixed_noise.data #gpu transform

    fake_u = netG(fixed_noise)
    fake_u = fake_u.cpu() if use_cuda else fake_u
    img = make_show(fake_u)
    
    # pick some pics and save
    vutil.save_image(img, os.path.join(path['outputs_aux'], "fake%s.png" % (epoch) ))
    
    # save net state
    torch.save(netG.state_dict(), os.path.join(path['models'], 'netG_epoch_%d' % (epoch)))
    torch.save(netD.state_dict(), os.path.join(path['models'], 'netD_epoch_%d' % (epoch)))
# Out:
# 第0周期，第0/600撮, 分类器Loss:4.71, 生成器Loss:2.35
# 第0周期，第100/600撮, 分类器Loss:4.16, 生成器Loss:2.33
# 第0周期，第200/600撮, 分类器Loss:3.73, 生成器Loss:2.35
# 第0周期，第300/600撮, 分类器Loss:3.35, 生成器Loss:2.31
# 第0周期，第400/600撮, 分类器Loss:3.17, 生成器Loss:2.34
# 第0周期，第500/600撮, 分类器Loss:3.16, 生成器Loss:2.25
# 第1周期，第0/600撮, 分类器Loss:3.13, 生成器Loss:2.14
# 第1周期，第100/600撮, 分类器Loss:3.02, 生成器Loss:2.13
# 第1周期，第200/600撮, 分类器Loss:2.93, 生成器Loss:2.15
# 第1周期，第300/600撮, 分类器Loss:2.91, 生成器Loss:2.05
# 第1周期，第400/600撮, 分类器Loss:2.77, 生成器Loss:2.05
# 第1周期，第500/600撮, 分类器Loss:2.57, 生成器Loss:2.04
# 第2周期，第0/600撮, 分类器Loss:2.50, 生成器Loss:2.11
# 第2周期，第100/600撮, 分类器Loss:2.46, 生成器Loss:2.06
# 第2周期，第200/600撮, 分类器Loss:2.51, 生成器Loss:1.98
# 第2周期，第300/600撮, 分类器Loss:2.38, 生成器Loss:1.94
# 第2周期，第400/600撮, 分类器Loss:2.27, 生成器Loss:2.03
# 第2周期，第500/600撮, 分类器Loss:2.19, 生成器Loss:2.04
# 第3周期，第0/600撮, 分类器Loss:2.33, 生成器Loss:2.09
# 第3周期，第100/600撮, 分类器Loss:2.08, 生成器Loss:2.07
# 第3周期，第200/600撮, 分类器Loss:1.98, 生成器Loss:2.04
# 第3周期，第300/600撮, 分类器Loss:1.98, 生成器Loss:2.05
# 第3周期，第400/600撮, 分类器Loss:1.97, 生成器Loss:2.16
# 第3周期，第500/600撮, 分类器Loss:1.77, 生成器Loss:2.10
# 第4周期，第0/600撮, 分类器Loss:1.84, 生成器Loss:2.10
# 第4周期，第100/600撮, 分类器Loss:1.77, 生成器Loss:2.02
# 第4周期，第200/600撮, 分类器Loss:1.91, 生成器Loss:1.93
# 第4周期，第300/600撮, 分类器Loss:1.77, 生成器Loss:2.00
# 第4周期，第400/600撮, 分类器Loss:1.78, 生成器Loss:1.97
# 第4周期，第500/600撮, 分类器Loss:1.71, 生成器Loss:1.94
# 第5周期，第0/600撮, 分类器Loss:1.75, 生成器Loss:1.92
# 第5周期，第100/600撮, 分类器Loss:1.74, 生成器Loss:2.00
# 第5周期，第200/600撮, 分类器Loss:1.61, 生成器Loss:2.01
# 第5周期，第300/600撮, 分类器Loss:1.66, 生成器Loss:2.03
# 第5周期，第400/600撮, 分类器Loss:1.67, 生成器Loss:1.96
# 第5周期，第500/600撮, 分类器Loss:1.59, 生成器Loss:2.04
# 第6周期，第0/600撮, 分类器Loss:1.48, 生成器Loss:2.03
# 第6周期，第100/600撮, 分类器Loss:1.51, 生成器Loss:2.11
# 第6周期，第200/600撮, 分类器Loss:1.47, 生成器Loss:2.12
# 第6周期，第300/600撮, 分类器Loss:1.48, 生成器Loss:1.99
# 第6周期，第400/600撮, 分类器Loss:1.45, 生成器Loss:1.99
# 第6周期，第500/600撮, 分类器Loss:1.45, 生成器Loss:2.11
# 第7周期，第0/600撮, 分类器Loss:1.44, 生成器Loss:2.13
# 第7周期，第100/600撮, 分类器Loss:1.40, 生成器Loss:2.01
# 第7周期，第200/600撮, 分类器Loss:1.46, 生成器Loss:2.11
# 第7周期，第300/600撮, 分类器Loss:1.36, 生成器Loss:2.08
# 第7周期，第400/600撮, 分类器Loss:1.24, 生成器Loss:2.08
# 第7周期，第500/600撮, 分类器Loss:1.24, 生成器Loss:2.18
# 第8周期，第0/600撮, 分类器Loss:1.28, 生成器Loss:2.10
# 第8周期，第100/600撮, 分类器Loss:1.17, 生成器Loss:2.12
# 第8周期，第200/600撮, 分类器Loss:1.10, 生成器Loss:2.30
# 第8周期，第300/600撮, 分类器Loss:1.12, 生成器Loss:2.24
# 第8周期，第400/600撮, 分类器Loss:1.08, 生成器Loss:2.48
# 第8周期，第500/600撮, 分类器Loss:1.16, 生成器Loss:2.21
# 第9周期，第0/600撮, 分类器Loss:1.16, 生成器Loss:2.21
# 第9周期，第100/600撮, 分类器Loss:1.18, 生成器Loss:2.19
# 第9周期，第200/600撮, 分类器Loss:1.12, 生成器Loss:2.29
# 第9周期，第300/600撮, 分类器Loss:1.02, 生成器Loss:2.29
# 第9周期，第400/600撮, 分类器Loss:1.11, 生成器Loss:2.13
# 第9周期，第500/600撮, 分类器Loss:1.03, 生成器Loss:2.20
# 第10周期，第0/600撮, 分类器Loss:0.98, 生成器Loss:2.36
# 第10周期，第100/600撮, 分类器Loss:1.04, 生成器Loss:2.28
# 第10周期，第200/600撮, 分类器Loss:0.99, 生成器Loss:2.30
# 第10周期，第300/600撮, 分类器Loss:1.04, 生成器Loss:2.41
# 第10周期，第400/600撮, 分类器Loss:1.03, 生成器Loss:2.50
# 第10周期，第500/600撮, 分类器Loss:1.05, 生成器Loss:2.42
# 第11周期，第0/600撮, 分类器Loss:1.06, 生成器Loss:2.40
# 第11周期，第100/600撮, 分类器Loss:0.90, 生成器Loss:2.44
# 第11周期，第200/600撮, 分类器Loss:0.88, 生成器Loss:2.31
# 第11周期，第300/600撮, 分类器Loss:0.99, 生成器Loss:2.40
# 第11周期，第400/600撮, 分类器Loss:1.00, 生成器Loss:2.43
# 第11周期，第500/600撮, 分类器Loss:0.94, 生成器Loss:2.48
# 第12周期，第0/600撮, 分类器Loss:0.94, 生成器Loss:2.62
# 第12周期，第100/600撮, 分类器Loss:0.81, 生成器Loss:2.63
# 第12周期，第200/600撮, 分类器Loss:0.85, 生成器Loss:2.44
# 第12周期，第300/600撮, 分类器Loss:0.95, 生成器Loss:2.50
# 第12周期，第400/600撮, 分类器Loss:0.86, 生成器Loss:2.58
# 第12周期，第500/600撮, 分类器Loss:0.86, 生成器Loss:2.52
# 第13周期，第0/600撮, 分类器Loss:0.84, 生成器Loss:2.60
# 第13周期，第100/600撮, 分类器Loss:0.72, 生成器Loss:2.59
# 第13周期，第200/600撮, 分类器Loss:0.77, 生成器Loss:2.57
# 第13周期，第300/600撮, 分类器Loss:0.84, 生成器Loss:2.67
# 第13周期，第400/600撮, 分类器Loss:0.86, 生成器Loss:2.44
# 第13周期，第500/600撮, 分类器Loss:0.78, 生成器Loss:2.59
# 第14周期，第0/600撮, 分类器Loss:0.69, 生成器Loss:2.61
# 第14周期，第100/600撮, 分类器Loss:0.84, 生成器Loss:2.62
# 第14周期，第200/600撮, 分类器Loss:0.85, 生成器Loss:2.71
# 第14周期，第300/600撮, 分类器Loss:0.80, 生成器Loss:2.72
# 第14周期，第400/600撮, 分类器Loss:0.83, 生成器Loss:2.68
# 第14周期，第500/600撮, 分类器Loss:0.84, 生成器Loss:2.72
# 第15周期，第0/600撮, 分类器Loss:0.72, 生成器Loss:2.68
# 第15周期，第100/600撮, 分类器Loss:0.78, 生成器Loss:2.69
# 第15周期，第200/600撮, 分类器Loss:0.68, 生成器Loss:2.74
# 第15周期，第300/600撮, 分类器Loss:0.69, 生成器Loss:2.84
# 第15周期，第400/600撮, 分类器Loss:0.78, 生成器Loss:2.80
# 第15周期，第500/600撮, 分类器Loss:0.68, 生成器Loss:2.73
# 第16周期，第0/600撮, 分类器Loss:0.69, 生成器Loss:2.71
# 第16周期，第100/600撮, 分类器Loss:0.73, 生成器Loss:2.83
# 第16周期，第200/600撮, 分类器Loss:0.77, 生成器Loss:3.03
# 第16周期，第300/600撮, 分类器Loss:0.70, 生成器Loss:2.83
# 第16周期，第400/600撮, 分类器Loss:0.75, 生成器Loss:2.72
# 第16周期，第500/600撮, 分类器Loss:0.70, 生成器Loss:2.83
# 第17周期，第0/600撮, 分类器Loss:0.66, 生成器Loss:2.93
# 第17周期，第100/600撮, 分类器Loss:0.72, 生成器Loss:2.77
# 第17周期，第200/600撮, 分类器Loss:0.70, 生成器Loss:2.85
# 第17周期，第300/600撮, 分类器Loss:0.64, 生成器Loss:2.92
# 第17周期，第400/600撮, 分类器Loss:0.75, 生成器Loss:2.94
# 第17周期，第500/600撮, 分类器Loss:0.62, 生成器Loss:2.84
# 第18周期，第0/600撮, 分类器Loss:0.67, 生成器Loss:2.90
# 第18周期，第100/600撮, 分类器Loss:0.68, 生成器Loss:2.97
# 第18周期，第200/600撮, 分类器Loss:0.63, 生成器Loss:2.93
# 第18周期，第300/600撮, 分类器Loss:0.63, 生成器Loss:2.86
# 第18周期，第400/600撮, 分类器Loss:0.64, 生成器Loss:2.80
# 第18周期，第500/600撮, 分类器Loss:0.67, 生成器Loss:2.90
# 第19周期，第0/600撮, 分类器Loss:0.67, 生成器Loss:2.58
# 第19周期，第100/600撮, 分类器Loss:0.66, 生成器Loss:2.96
# 第19周期，第200/600撮, 分类器Loss:0.64, 生成器Loss:2.92
# 第19周期，第300/600撮, 分类器Loss:0.57, 生成器Loss:2.95
# 第19周期，第400/600撮, 分类器Loss:0.54, 生成器Loss:2.95
# 第19周期，第500/600撮, 分类器Loss:0.58, 生成器Loss:2.89
# 第20周期，第0/600撮, 分类器Loss:0.53, 生成器Loss:2.96
# 第20周期，第100/600撮, 分类器Loss:0.71, 生成器Loss:3.06
# 第20周期，第200/600撮, 分类器Loss:0.64, 生成器Loss:3.03
# 第20周期，第300/600撮, 分类器Loss:0.56, 生成器Loss:2.88
# 第20周期，第400/600撮, 分类器Loss:0.54, 生成器Loss:2.96
# 第20周期，第500/600撮, 分类器Loss:0.53, 生成器Loss:3.07
# 第21周期，第0/600撮, 分类器Loss:0.61, 生成器Loss:3.03
# 第21周期，第100/600撮, 分类器Loss:0.61, 生成器Loss:2.92
# 第21周期，第200/600撮, 分类器Loss:0.61, 生成器Loss:2.98
# 第21周期，第300/600撮, 分类器Loss:0.49, 生成器Loss:3.12
# 第21周期，第400/600撮, 分类器Loss:0.54, 生成器Loss:3.05
# 第21周期，第500/600撮, 分类器Loss:0.67, 生成器Loss:3.00
# 第22周期，第0/600撮, 分类器Loss:0.53, 生成器Loss:3.15
# 第22周期，第100/600撮, 分类器Loss:0.55, 生成器Loss:2.97
# 第22周期，第200/600撮, 分类器Loss:0.54, 生成器Loss:3.00
# 第22周期，第300/600撮, 分类器Loss:0.42, 生成器Loss:3.00
# 第22周期，第400/600撮, 分类器Loss:0.53, 生成器Loss:3.04
# 第22周期，第500/600撮, 分类器Loss:0.59, 生成器Loss:3.06
# 第23周期，第0/600撮, 分类器Loss:0.53, 生成器Loss:3.26
# 第23周期，第100/600撮, 分类器Loss:0.47, 生成器Loss:2.99
# 第23周期，第200/600撮, 分类器Loss:0.61, 生成器Loss:3.12
# 第23周期，第300/600撮, 分类器Loss:0.60, 生成器Loss:3.11
# 第23周期，第400/600撮, 分类器Loss:0.54, 生成器Loss:3.11
# 第23周期，第500/600撮, 分类器Loss:0.58, 生成器Loss:2.92
# 第24周期，第0/600撮, 分类器Loss:0.51, 生成器Loss:3.29
# 第24周期，第100/600撮, 分类器Loss:0.66, 生成器Loss:3.20
# 第24周期，第200/600撮, 分类器Loss:0.54, 生成器Loss:3.20
# 第24周期，第300/600撮, 分类器Loss:0.53, 生成器Loss:3.12
# 第24周期，第400/600撮, 分类器Loss:0.58, 生成器Loss:3.10
# 第24周期，第500/600撮, 分类器Loss:0.50, 生成器Loss:3.22
# 第25周期，第0/600撮, 分类器Loss:0.49, 生成器Loss:3.25
# 第25周期，第100/600撮, 分类器Loss:0.44, 生成器Loss:3.20
# 第25周期，第200/600撮, 分类器Loss:0.42, 生成器Loss:3.10
# 第25周期，第300/600撮, 分类器Loss:0.45, 生成器Loss:3.48
# 第25周期，第400/600撮, 分类器Loss:0.49, 生成器Loss:3.27
# 第25周期，第500/600撮, 分类器Loss:0.54, 生成器Loss:3.30
# 第26周期，第0/600撮, 分类器Loss:0.57, 生成器Loss:3.31
# 第26周期，第100/600撮, 分类器Loss:0.49, 生成器Loss:3.26
# 第26周期，第200/600撮, 分类器Loss:0.47, 生成器Loss:3.37
# 第26周期，第300/600撮, 分类器Loss:0.49, 生成器Loss:3.40
# 第26周期，第400/600撮, 分类器Loss:0.57, 生成器Loss:3.39
# 第26周期，第500/600撮, 分类器Loss:0.50, 生成器Loss:3.46
# 第27周期，第0/600撮, 分类器Loss:0.42, 生成器Loss:3.42
# 第27周期，第100/600撮, 分类器Loss:0.34, 生成器Loss:3.48
# 第27周期，第200/600撮, 分类器Loss:0.44, 生成器Loss:3.39
# 第27周期，第300/600撮, 分类器Loss:0.39, 生成器Loss:3.28
# 第27周期，第400/600撮, 分类器Loss:0.39, 生成器Loss:3.30
# 第27周期，第500/600撮, 分类器Loss:0.32, 生成器Loss:3.27
# 第28周期，第0/600撮, 分类器Loss:0.45, 生成器Loss:3.36
# 第28周期，第100/600撮, 分类器Loss:0.41, 生成器Loss:3.23
# 第28周期，第200/600撮, 分类器Loss:0.53, 生成器Loss:3.37
# 第28周期，第300/600撮, 分类器Loss:0.38, 生成器Loss:3.30
# 第28周期，第400/600撮, 分类器Loss:0.48, 生成器Loss:3.30
# 第28周期，第500/600撮, 分类器Loss:0.38, 生成器Loss:3.54
# 第29周期，第0/600撮, 分类器Loss:0.41, 生成器Loss:3.37
# 第29周期，第100/600撮, 分类器Loss:0.34, 生成器Loss:3.54
# 第29周期，第200/600撮, 分类器Loss:0.46, 生成器Loss:3.55
# 第29周期，第300/600撮, 分类器Loss:0.36, 生成器Loss:3.53
# 第29周期，第400/600撮, 分类器Loss:0.39, 生成器Loss:3.47
# 第29周期，第500/600撮, 分类器Loss:0.39, 生成器Loss:3.65
# 第30周期，第0/600撮, 分类器Loss:0.31, 生成器Loss:3.56
# 第30周期，第100/600撮, 分类器Loss:0.48, 生成器Loss:3.54
# 第30周期，第200/600撮, 分类器Loss:0.31, 生成器Loss:3.58
# 第30周期，第300/600撮, 分类器Loss:0.33, 生成器Loss:3.61
# 第30周期，第400/600撮, 分类器Loss:0.48, 生成器Loss:3.59
# 第30周期，第500/600撮, 分类器Loss:0.41, 生成器Loss:3.73
# 第31周期，第0/600撮, 分类器Loss:0.37, 生成器Loss:3.65
# 第31周期，第100/600撮, 分类器Loss:0.38, 生成器Loss:3.86
# 第31周期，第200/600撮, 分类器Loss:0.38, 生成器Loss:3.79
# 第31周期，第300/600撮, 分类器Loss:0.36, 生成器Loss:3.78
# 第31周期，第400/600撮, 分类器Loss:0.44, 生成器Loss:3.77
# 第31周期，第500/600撮, 分类器Loss:0.35, 生成器Loss:3.71
# 第32周期，第0/600撮, 分类器Loss:0.37, 生成器Loss:3.72
# 第32周期，第100/600撮, 分类器Loss:0.31, 生成器Loss:3.71
# 第32周期，第200/600撮, 分类器Loss:0.51, 生成器Loss:3.86
# 第32周期，第300/600撮, 分类器Loss:0.25, 生成器Loss:3.82
# 第32周期，第400/600撮, 分类器Loss:0.40, 生成器Loss:3.82
# 第32周期，第500/600撮, 分类器Loss:0.39, 生成器Loss:3.78
# 第33周期，第0/600撮, 分类器Loss:0.39, 生成器Loss:3.79
# 第33周期，第100/600撮, 分类器Loss:0.36, 生成器Loss:3.64
# 第33周期，第200/600撮, 分类器Loss:0.46, 生成器Loss:3.78
# 第33周期，第300/600撮, 分类器Loss:0.43, 生成器Loss:3.79
# 第33周期，第400/600撮, 分类器Loss:0.35, 生成器Loss:3.91
# 第33周期，第500/600撮, 分类器Loss:0.34, 生成器Loss:3.78
# 第34周期，第0/600撮, 分类器Loss:0.41, 生成器Loss:3.62
# 第34周期，第100/600撮, 分类器Loss:0.35, 生成器Loss:3.80
# 第34周期，第200/600撮, 分类器Loss:0.29, 生成器Loss:3.83
# 第34周期，第300/600撮, 分类器Loss:0.40, 生成器Loss:3.96
# 第34周期，第400/600撮, 分类器Loss:0.33, 生成器Loss:3.82
# 第34周期，第500/600撮, 分类器Loss:0.32, 生成器Loss:3.96
# 第35周期，第0/600撮, 分类器Loss:0.39, 生成器Loss:3.89
# 第35周期，第100/600撮, 分类器Loss:0.40, 生成器Loss:3.79
# 第35周期，第200/600撮, 分类器Loss:0.31, 生成器Loss:3.69
# 第35周期，第300/600撮, 分类器Loss:0.39, 生成器Loss:3.80
# 第35周期，第400/600撮, 分类器Loss:0.30, 生成器Loss:3.96
# 第35周期，第500/600撮, 分类器Loss:0.39, 生成器Loss:3.92
# 第36周期，第0/600撮, 分类器Loss:0.38, 生成器Loss:3.90
# 第36周期，第100/600撮, 分类器Loss:0.34, 生成器Loss:3.95
# 第36周期，第200/600撮, 分类器Loss:0.26, 生成器Loss:3.86
# 第36周期，第300/600撮, 分类器Loss:0.30, 生成器Loss:4.00
# 第36周期，第400/600撮, 分类器Loss:0.46, 生成器Loss:3.83
# 第36周期，第500/600撮, 分类器Loss:0.42, 生成器Loss:3.97
# 第37周期，第0/600撮, 分类器Loss:0.28, 生成器Loss:4.00
# 第37周期，第100/600撮, 分类器Loss:0.34, 生成器Loss:4.18
# 第37周期，第200/600撮, 分类器Loss:0.28, 生成器Loss:3.98
# 第37周期，第300/600撮, 分类器Loss:0.30, 生成器Loss:4.09
# 第37周期，第400/600撮, 分类器Loss:0.30, 生成器Loss:4.05
# 第37周期，第500/600撮, 分类器Loss:0.30, 生成器Loss:3.96
# 第38周期，第0/600撮, 分类器Loss:0.39, 生成器Loss:3.91
# 第38周期，第100/600撮, 分类器Loss:0.30, 生成器Loss:3.98
# 第38周期，第200/600撮, 分类器Loss:0.35, 生成器Loss:3.92
# 第38周期，第300/600撮, 分类器Loss:0.25, 生成器Loss:4.12
# 第38周期，第400/600撮, 分类器Loss:0.36, 生成器Loss:3.81
# 第38周期，第500/600撮, 分类器Loss:0.32, 生成器Loss:4.03
# 第39周期，第0/600撮, 分类器Loss:0.29, 生成器Loss:4.26
# 第39周期，第100/600撮, 分类器Loss:0.31, 生成器Loss:4.01
# 第39周期，第200/600撮, 分类器Loss:0.21, 生成器Loss:4.02
# 第39周期，第300/600撮, 分类器Loss:0.32, 生成器Loss:4.02
# 第39周期，第400/600撮, 分类器Loss:0.33, 生成器Loss:3.85
# 第39周期，第500/600撮, 分类器Loss:0.32, 生成器Loss:4.01
# 第40周期，第0/600撮, 分类器Loss:0.37, 生成器Loss:3.96
# 第40周期，第100/600撮, 分类器Loss:0.23, 生成器Loss:4.14
# 第40周期，第200/600撮, 分类器Loss:0.36, 生成器Loss:4.06
# 第40周期，第300/600撮, 分类器Loss:0.18, 生成器Loss:4.26
# 第40周期，第400/600撮, 分类器Loss:0.30, 生成器Loss:4.13
# 第40周期，第500/600撮, 分类器Loss:0.31, 生成器Loss:4.27
# 第41周期，第0/600撮, 分类器Loss:0.18, 生成器Loss:4.14
# 第41周期，第100/600撮, 分类器Loss:0.24, 生成器Loss:4.12
# 第41周期，第200/600撮, 分类器Loss:0.27, 生成器Loss:4.19
# 第41周期，第300/600撮, 分类器Loss:0.28, 生成器Loss:4.18
# 第41周期，第400/600撮, 分类器Loss:0.37, 生成器Loss:4.25
# 第41周期，第500/600撮, 分类器Loss:0.29, 生成器Loss:4.20
# 第42周期，第0/600撮, 分类器Loss:0.20, 生成器Loss:4.19
# 第42周期，第100/600撮, 分类器Loss:0.30, 生成器Loss:4.19
# 第42周期，第200/600撮, 分类器Loss:0.31, 生成器Loss:4.14
# 第42周期，第300/600撮, 分类器Loss:0.24, 生成器Loss:4.19
# 第42周期，第400/600撮, 分类器Loss:0.23, 生成器Loss:4.06
# 第42周期，第500/600撮, 分类器Loss:0.19, 生成器Loss:4.07
# 第43周期，第0/600撮, 分类器Loss:0.33, 生成器Loss:4.12
# 第43周期，第100/600撮, 分类器Loss:0.27, 生成器Loss:4.16
# 第43周期，第200/600撮, 分类器Loss:0.23, 生成器Loss:3.96
# 第43周期，第300/600撮, 分类器Loss:0.38, 生成器Loss:4.03
# 第43周期，第400/600撮, 分类器Loss:0.26, 生成器Loss:3.93
# 第43周期，第500/600撮, 分类器Loss:0.17, 生成器Loss:4.13
# 第44周期，第0/600撮, 分类器Loss:0.24, 生成器Loss:4.13
# 第44周期，第100/600撮, 分类器Loss:0.20, 生成器Loss:4.16
# 第44周期，第200/600撮, 分类器Loss:0.19, 生成器Loss:4.07
# 第44周期，第300/600撮, 分类器Loss:0.29, 生成器Loss:4.00
# 第44周期，第400/600撮, 分类器Loss:0.28, 生成器Loss:4.31
# 第44周期，第500/600撮, 分类器Loss:0.29, 生成器Loss:4.18
# 第45周期，第0/600撮, 分类器Loss:0.29, 生成器Loss:4.16
# 第45周期，第100/600撮, 分类器Loss:0.27, 生成器Loss:4.23
# 第45周期，第200/600撮, 分类器Loss:0.26, 生成器Loss:4.42
# 第45周期，第300/600撮, 分类器Loss:0.30, 生成器Loss:4.20
# 第45周期，第400/600撮, 分类器Loss:0.35, 生成器Loss:4.09
# 第45周期，第500/600撮, 分类器Loss:0.19, 生成器Loss:4.04
# 第46周期，第0/600撮, 分类器Loss:0.19, 生成器Loss:4.13
# 第46周期，第100/600撮, 分类器Loss:0.28, 生成器Loss:4.10
# 第46周期，第200/600撮, 分类器Loss:0.26, 生成器Loss:3.99
# 第46周期，第300/600撮, 分类器Loss:0.27, 生成器Loss:4.17
# 第46周期，第400/600撮, 分类器Loss:0.28, 生成器Loss:4.15
# 第46周期，第500/600撮, 分类器Loss:0.29, 生成器Loss:4.19
# 第47周期，第0/600撮, 分类器Loss:0.20, 生成器Loss:4.10
# 第47周期，第100/600撮, 分类器Loss:0.25, 生成器Loss:4.20
# 第47周期，第200/600撮, 分类器Loss:0.22, 生成器Loss:4.18
# 第47周期，第300/600撮, 分类器Loss:0.27, 生成器Loss:4.20
# 第47周期，第400/600撮, 分类器Loss:0.20, 生成器Loss:4.16
# 第47周期，第500/600撮, 分类器Loss:0.30, 生成器Loss:3.98
# 第48周期，第0/600撮, 分类器Loss:0.27, 生成器Loss:4.25
# 第48周期，第100/600撮, 分类器Loss:0.23, 生成器Loss:4.28
# 第48周期，第200/600撮, 分类器Loss:0.18, 生成器Loss:4.38
# 第48周期，第300/600撮, 分类器Loss:0.23, 生成器Loss:4.11
# 第48周期，第400/600撮, 分类器Loss:0.17, 生成器Loss:4.15
# 第48周期，第500/600撮, 分类器Loss:0.28, 生成器Loss:3.92
# 第49周期，第0/600撮, 分类器Loss:0.33, 生成器Loss:4.06
# 第49周期，第100/600撮, 分类器Loss:0.22, 生成器Loss:4.20
# 第49周期，第200/600撮, 分类器Loss:0.32, 生成器Loss:4.35
# 第49周期，第300/600撮, 分类器Loss:0.21, 生成器Loss:4.31
# 第49周期，第400/600撮, 分类器Loss:0.24, 生成器Loss:4.47
# 第49周期，第500/600撮, 分类器Loss:0.33, 生成器Loss:4.27
# 第50周期，第0/600撮, 分类器Loss:0.30, 生成器Loss:4.21
# 第50周期，第100/600撮, 分类器Loss:0.29, 生成器Loss:3.98
# 第50周期，第200/600撮, 分类器Loss:0.28, 生成器Loss:3.93
# 第50周期，第300/600撮, 分类器Loss:0.32, 生成器Loss:3.87
# 第50周期，第400/600撮, 分类器Loss:0.33, 生成器Loss:3.63
# 第50周期，第500/600撮, 分类器Loss:0.20, 生成器Loss:4.33
# 第51周期，第0/600撮, 分类器Loss:0.30, 生成器Loss:3.80
# 第51周期，第100/600撮, 分类器Loss:0.26, 生成器Loss:4.10
# 第51周期，第200/600撮, 分类器Loss:0.22, 生成器Loss:4.11
# 第51周期，第300/600撮, 分类器Loss:0.38, 生成器Loss:3.68
# 第51周期，第400/600撮, 分类器Loss:0.24, 生成器Loss:4.38
# 第51周期，第500/600撮, 分类器Loss:0.33, 生成器Loss:3.78
# 第52周期，第0/600撮, 分类器Loss:0.25, 生成器Loss:3.65
# 第52周期，第100/600撮, 分类器Loss:0.20, 生成器Loss:3.68
# 第52周期，第200/600撮, 分类器Loss:0.26, 生成器Loss:3.93
# 第52周期，第300/600撮, 分类器Loss:0.27, 生成器Loss:4.05
# 第52周期，第400/600撮, 分类器Loss:0.24, 生成器Loss:3.77
# 第52周期，第500/600撮, 分类器Loss:0.26, 生成器Loss:4.12
# 第53周期，第0/600撮, 分类器Loss:0.29, 生成器Loss:3.86
# 第53周期，第100/600撮, 分类器Loss:0.25, 生成器Loss:4.23
# 第53周期，第200/600撮, 分类器Loss:0.26, 生成器Loss:3.88
# 第53周期，第300/600撮, 分类器Loss:0.28, 生成器Loss:4.16
# 第53周期，第400/600撮, 分类器Loss:0.31, 生成器Loss:3.66
# 第53周期，第500/600撮, 分类器Loss:0.22, 生成器Loss:3.86
# 第54周期，第0/600撮, 分类器Loss:0.16, 生成器Loss:3.86
# 第54周期，第100/600撮, 分类器Loss:0.28, 生成器Loss:3.65
# 第54周期，第200/600撮, 分类器Loss:0.34, 生成器Loss:3.51
# 第54周期，第300/600撮, 分类器Loss:0.37, 生成器Loss:3.74
# 第54周期，第400/600撮, 分类器Loss:0.34, 生成器Loss:3.65
# 第54周期，第500/600撮, 分类器Loss:0.22, 生成器Loss:3.95
# 第55周期，第0/600撮, 分类器Loss:0.41, 生成器Loss:3.78
# 第55周期，第100/600撮, 分类器Loss:0.21, 生成器Loss:3.83
# 第55周期，第200/600撮, 分类器Loss:0.25, 生成器Loss:4.00
# 第55周期，第300/600撮, 分类器Loss:0.28, 生成器Loss:3.81
# 第55周期，第400/600撮, 分类器Loss:0.20, 生成器Loss:3.90
# 第55周期，第500/600撮, 分类器Loss:0.34, 生成器Loss:3.57
# 第56周期，第0/600撮, 分类器Loss:0.29, 生成器Loss:3.78
# 第56周期，第100/600撮, 分类器Loss:0.28, 生成器Loss:3.78
# 第56周期，第200/600撮, 分类器Loss:0.25, 生成器Loss:3.78
# 第56周期，第300/600撮, 分类器Loss:0.26, 生成器Loss:4.03
# 第56周期，第400/600撮, 分类器Loss:0.29, 生成器Loss:3.62
# 第56周期，第500/600撮, 分类器Loss:0.23, 生成器Loss:3.70
# 第57周期，第0/600撮, 分类器Loss:0.27, 生成器Loss:4.12
# 第57周期，第100/600撮, 分类器Loss:0.26, 生成器Loss:3.64
# 第57周期，第200/600撮, 分类器Loss:0.30, 生成器Loss:3.87
# 第57周期，第300/600撮, 分类器Loss:0.22, 生成器Loss:3.81
# 第57周期，第400/600撮, 分类器Loss:0.27, 生成器Loss:3.59
# 第57周期，第500/600撮, 分类器Loss:0.27, 生成器Loss:3.56
# 第58周期，第0/600撮, 分类器Loss:0.35, 生成器Loss:3.74
# 第58周期，第100/600撮, 分类器Loss:0.35, 生成器Loss:3.54
# 第58周期，第200/600撮, 分类器Loss:0.20, 生成器Loss:3.85
# 第58周期，第300/600撮, 分类器Loss:0.30, 生成器Loss:3.52
# 第58周期，第400/600撮, 分类器Loss:0.30, 生成器Loss:3.54
# 第58周期，第500/600撮, 分类器Loss:0.33, 生成器Loss:3.64
# 第59周期，第0/600撮, 分类器Loss:0.31, 生成器Loss:3.63
# 第59周期，第100/600撮, 分类器Loss:0.35, 生成器Loss:3.48
# 第59周期，第200/600撮, 分类器Loss:0.22, 生成器Loss:3.87
# 第59周期，第300/600撮, 分类器Loss:0.25, 生成器Loss:3.61
# 第59周期，第400/600撮, 分类器Loss:0.31, 生成器Loss:3.66
# 第59周期，第500/600撮, 分类器Loss:0.24, 生成器Loss:3.87
# 第60周期，第0/600撮, 分类器Loss:0.31, 生成器Loss:3.77
# 第60周期，第100/600撮, 分类器Loss:0.28, 生成器Loss:3.88
# 第60周期，第200/600撮, 分类器Loss:0.27, 生成器Loss:3.74
# 第60周期，第300/600撮, 分类器Loss:0.37, 生成器Loss:3.66
# 第60周期，第400/600撮, 分类器Loss:0.29, 生成器Loss:3.57
# 第60周期，第500/600撮, 分类器Loss:0.38, 生成器Loss:3.89
# 第61周期，第0/600撮, 分类器Loss:0.26, 生成器Loss:3.66
# 第61周期，第100/600撮, 分类器Loss:0.22, 生成器Loss:3.73
# 第61周期，第200/600撮, 分类器Loss:0.30, 生成器Loss:3.71
# 第61周期，第300/600撮, 分类器Loss:0.35, 生成器Loss:3.53
# 第61周期，第400/600撮, 分类器Loss:0.31, 生成器Loss:3.54
# 第61周期，第500/600撮, 分类器Loss:0.38, 生成器Loss:3.71
# 第62周期，第0/600撮, 分类器Loss:0.25, 生成器Loss:3.91
# 第62周期，第100/600撮, 分类器Loss:0.24, 生成器Loss:3.61
# 第62周期，第200/600撮, 分类器Loss:0.21, 生成器Loss:3.62
# 第62周期，第300/600撮, 分类器Loss:0.23, 生成器Loss:3.51
# 第62周期，第400/600撮, 分类器Loss:0.25, 生成器Loss:3.75
# 第62周期，第500/600撮, 分类器Loss:0.28, 生成器Loss:3.47
# 第63周期，第0/600撮, 分类器Loss:0.23, 生成器Loss:3.78
# 第63周期，第100/600撮, 分类器Loss:0.25, 生成器Loss:3.67
# 第63周期，第200/600撮, 分类器Loss:0.24, 生成器Loss:3.96
# 第63周期，第300/600撮, 分类器Loss:0.47, 生成器Loss:3.55
# 第63周期，第400/600撮, 分类器Loss:0.22, 生成器Loss:3.51
# 第63周期，第500/600撮, 分类器Loss:0.26, 生成器Loss:3.67
# 第64周期，第0/600撮, 分类器Loss:0.27, 生成器Loss:3.54
# 第64周期，第100/600撮, 分类器Loss:0.31, 生成器Loss:3.68
# 第64周期，第200/600撮, 分类器Loss:0.24, 生成器Loss:3.31
# 第64周期，第300/600撮, 分类器Loss:0.29, 生成器Loss:3.74
# 第64周期，第400/600撮, 分类器Loss:0.29, 生成器Loss:3.97
# 第64周期，第500/600撮, 分类器Loss:0.28, 生成器Loss:3.78
# 第65周期，第0/600撮, 分类器Loss:0.25, 生成器Loss:4.13
# 第65周期，第100/600撮, 分类器Loss:0.21, 生成器Loss:4.07
# 第65周期，第200/600撮, 分类器Loss:0.21, 生成器Loss:3.64
# 第65周期，第300/600撮, 分类器Loss:0.26, 生成器Loss:4.01
# 第65周期，第400/600撮, 分类器Loss:0.20, 生成器Loss:3.29
# 第65周期，第500/600撮, 分类器Loss:0.23, 生成器Loss:3.78
# 第66周期，第0/600撮, 分类器Loss:0.26, 生成器Loss:4.14
# 第66周期，第100/600撮, 分类器Loss:0.26, 生成器Loss:3.78
# 第66周期，第200/600撮, 分类器Loss:0.24, 生成器Loss:3.92
# 第66周期，第300/600撮, 分类器Loss:0.32, 生成器Loss:3.77
# 第66周期，第400/600撮, 分类器Loss:0.27, 生成器Loss:3.81
# 第66周期，第500/600撮, 分类器Loss:0.24, 生成器Loss:3.76
# 第67周期，第0/600撮, 分类器Loss:0.31, 生成器Loss:4.06
# 第67周期，第100/600撮, 分类器Loss:0.37, 生成器Loss:3.58
# 第67周期，第200/600撮, 分类器Loss:0.26, 生成器Loss:4.01
# 第67周期，第300/600撮, 分类器Loss:0.23, 生成器Loss:4.06
# 第67周期，第400/600撮, 分类器Loss:0.23, 生成器Loss:3.76
# 第67周期，第500/600撮, 分类器Loss:0.25, 生成器Loss:3.78
# 第68周期，第0/600撮, 分类器Loss:0.24, 生成器Loss:4.07
# 第68周期，第100/600撮, 分类器Loss:0.20, 生成器Loss:4.29
# 第68周期，第200/600撮, 分类器Loss:0.31, 生成器Loss:3.39
# 第68周期，第300/600撮, 分类器Loss:0.30, 生成器Loss:4.24
# 第68周期，第400/600撮, 分类器Loss:0.22, 生成器Loss:3.75
# 第68周期，第500/600撮, 分类器Loss:0.29, 生成器Loss:3.74
# 第69周期，第0/600撮, 分类器Loss:0.24, 生成器Loss:3.83
# 第69周期，第100/600撮, 分类器Loss:0.31, 生成器Loss:3.90
# 第69周期，第200/600撮, 分类器Loss:0.30, 生成器Loss:3.92
# 第69周期，第300/600撮, 分类器Loss:0.38, 生成器Loss:3.28
# 第69周期，第400/600撮, 分类器Loss:0.33, 生成器Loss:3.57
# 第69周期，第500/600撮, 分类器Loss:0.35, 生成器Loss:3.69
# 第70周期，第0/600撮, 分类器Loss:0.17, 生成器Loss:4.00
# 第70周期，第100/600撮, 分类器Loss:0.20, 生成器Loss:4.22
# 第70周期，第200/600撮, 分类器Loss:0.32, 生成器Loss:3.66
# 第70周期，第300/600撮, 分类器Loss:0.20, 生成器Loss:4.00
# 第70周期，第400/600撮, 分类器Loss:0.20, 生成器Loss:3.90
# 第70周期，第500/600撮, 分类器Loss:0.21, 生成器Loss:4.32
# 第71周期，第0/600撮, 分类器Loss:0.20, 生成器Loss:3.78
# 第71周期，第100/600撮, 分类器Loss:0.21, 生成器Loss:4.43
# 第71周期，第200/600撮, 分类器Loss:0.20, 生成器Loss:3.49
# 第71周期，第300/600撮, 分类器Loss:0.23, 生成器Loss:3.97
# 第71周期，第400/600撮, 分类器Loss:0.23, 生成器Loss:4.20
# 第71周期，第500/600撮, 分类器Loss:0.21, 生成器Loss:4.27
# 第72周期，第0/600撮, 分类器Loss:0.27, 生成器Loss:3.77
# 第72周期，第100/600撮, 分类器Loss:0.24, 生成器Loss:4.13
# 第72周期，第200/600撮, 分类器Loss:0.19, 生成器Loss:4.20
# 第72周期，第300/600撮, 分类器Loss:0.23, 生成器Loss:3.82
# 第72周期，第400/600撮, 分类器Loss:0.22, 生成器Loss:4.23
# 第72周期，第500/600撮, 分类器Loss:0.25, 生成器Loss:4.26
# 第73周期，第0/600撮, 分类器Loss:0.23, 生成器Loss:4.40
# 第73周期，第100/600撮, 分类器Loss:0.20, 生成器Loss:4.35
# 第73周期，第200/600撮, 分类器Loss:0.13, 生成器Loss:4.47
# 第73周期，第300/600撮, 分类器Loss:0.28, 生成器Loss:4.02
# 第73周期，第400/600撮, 分类器Loss:0.23, 生成器Loss:4.06
# 第73周期，第500/600撮, 分类器Loss:0.21, 生成器Loss:4.18
# 第74周期，第0/600撮, 分类器Loss:0.23, 生成器Loss:4.11
# 第74周期，第100/600撮, 分类器Loss:0.24, 生成器Loss:4.28
# 第74周期，第200/600撮, 分类器Loss:0.24, 生成器Loss:4.19
# 第74周期，第300/600撮, 分类器Loss:0.20, 生成器Loss:3.56
# 第74周期，第400/600撮, 分类器Loss:0.20, 生成器Loss:3.99
# 第74周期，第500/600撮, 分类器Loss:0.22, 生成器Loss:4.05
# 第75周期，第0/600撮, 分类器Loss:0.25, 生成器Loss:4.12
# 第75周期，第100/600撮, 分类器Loss:0.15, 生成器Loss:4.34
# 第75周期，第200/600撮, 分类器Loss:0.14, 生成器Loss:4.09
# 第75周期，第300/600撮, 分类器Loss:0.23, 生成器Loss:4.35
# 第75周期，第400/600撮, 分类器Loss:0.26, 生成器Loss:4.24
# 第75周期，第500/600撮, 分类器Loss:0.26, 生成器Loss:4.35
# 第76周期，第0/600撮, 分类器Loss:0.24, 生成器Loss:3.81
# 第76周期，第100/600撮, 分类器Loss:0.18, 生成器Loss:4.26
# 第76周期，第200/600撮, 分类器Loss:0.24, 生成器Loss:4.06
# 第76周期，第300/600撮, 分类器Loss:0.18, 生成器Loss:3.98
# 第76周期，第400/600撮, 分类器Loss:0.19, 生成器Loss:4.20
# 第76周期，第500/600撮, 分类器Loss:0.23, 生成器Loss:4.41
# 第77周期，第0/600撮, 分类器Loss:0.23, 生成器Loss:4.03
# 第77周期，第100/600撮, 分类器Loss:0.19, 生成器Loss:4.01
# 第77周期，第200/600撮, 分类器Loss:0.16, 生成器Loss:3.87
# 第77周期，第300/600撮, 分类器Loss:0.22, 生成器Loss:4.04
# 第77周期，第400/600撮, 分类器Loss:0.26, 生成器Loss:4.04
# 第77周期，第500/600撮, 分类器Loss:0.25, 生成器Loss:3.82
# 第78周期，第0/600撮, 分类器Loss:0.21, 生成器Loss:4.39
# 第78周期，第100/600撮, 分类器Loss:0.20, 生成器Loss:4.41
# 第78周期，第200/600撮, 分类器Loss:0.20, 生成器Loss:4.30
# 第78周期，第300/600撮, 分类器Loss:0.20, 生成器Loss:4.24
# 第78周期，第400/600撮, 分类器Loss:0.16, 生成器Loss:3.91
# 第78周期，第500/600撮, 分类器Loss:0.28, 生成器Loss:4.61
# 第79周期，第0/600撮, 分类器Loss:0.29, 生成器Loss:4.37
# 第79周期，第100/600撮, 分类器Loss:0.17, 生成器Loss:4.41
# 第79周期，第200/600撮, 分类器Loss:0.13, 生成器Loss:4.09
# 第79周期，第300/600撮, 分类器Loss:0.18, 生成器Loss:4.23
# 第79周期，第400/600撮, 分类器Loss:0.19, 生成器Loss:4.02
# 第79周期，第500/600撮, 分类器Loss:0.19, 生成器Loss:3.89
# 第80周期，第0/600撮, 分类器Loss:0.20, 生成器Loss:4.24
# 第80周期，第100/600撮, 分类器Loss:0.21, 生成器Loss:4.40
# 第80周期，第200/600撮, 分类器Loss:0.21, 生成器Loss:4.09
# 第80周期，第300/600撮, 分类器Loss:0.20, 生成器Loss:4.37
# 第80周期，第400/600撮, 分类器Loss:0.18, 生成器Loss:4.43
# 第80周期，第500/600撮, 分类器Loss:0.17, 生成器Loss:4.31
# 第81周期，第0/600撮, 分类器Loss:0.16, 生成器Loss:4.63
# 第81周期，第100/600撮, 分类器Loss:0.16, 生成器Loss:4.61
# 第81周期，第200/600撮, 分类器Loss:0.23, 生成器Loss:4.32
# 第81周期，第300/600撮, 分类器Loss:0.29, 生成器Loss:4.56
# 第81周期，第400/600撮, 分类器Loss:0.17, 生成器Loss:4.30
# 第81周期，第500/600撮, 分类器Loss:0.22, 生成器Loss:4.32
# 第82周期，第0/600撮, 分类器Loss:0.24, 生成器Loss:3.98
# 第82周期，第100/600撮, 分类器Loss:0.15, 生成器Loss:4.27
# 第82周期，第200/600撮, 分类器Loss:0.18, 生成器Loss:4.86
# 第82周期，第300/600撮, 分类器Loss:0.12, 生成器Loss:4.22
# 第82周期，第400/600撮, 分类器Loss:0.16, 生成器Loss:4.54
# 第82周期，第500/600撮, 分类器Loss:0.15, 生成器Loss:3.99
# 第83周期，第0/600撮, 分类器Loss:0.26, 生成器Loss:4.31
# 第83周期，第100/600撮, 分类器Loss:0.20, 生成器Loss:3.95
# 第83周期，第200/600撮, 分类器Loss:0.22, 生成器Loss:4.41
# 第83周期，第300/600撮, 分类器Loss:0.17, 生成器Loss:4.53
# 第83周期，第400/600撮, 分类器Loss:0.13, 生成器Loss:4.52
# 第83周期，第500/600撮, 分类器Loss:0.20, 生成器Loss:4.55
# 第84周期，第0/600撮, 分类器Loss:0.20, 生成器Loss:4.20
# 第84周期，第100/600撮, 分类器Loss:0.24, 生成器Loss:4.06
# 第84周期，第200/600撮, 分类器Loss:0.18, 生成器Loss:4.27
# 第84周期，第300/600撮, 分类器Loss:0.13, 生成器Loss:4.92
# 第84周期，第400/600撮, 分类器Loss:0.16, 生成器Loss:4.13
# 第84周期，第500/600撮, 分类器Loss:0.25, 生成器Loss:4.12
# 第85周期，第0/600撮, 分类器Loss:0.14, 生成器Loss:4.33
# 第85周期，第100/600撮, 分类器Loss:0.19, 生成器Loss:4.99
# 第85周期，第200/600撮, 分类器Loss:0.17, 生成器Loss:4.42
# 第85周期，第300/600撮, 分类器Loss:0.15, 生成器Loss:4.43
# 第85周期，第400/600撮, 分类器Loss:0.16, 生成器Loss:4.53
# 第85周期，第500/600撮, 分类器Loss:0.14, 生成器Loss:4.19
# 第86周期，第0/600撮, 分类器Loss:0.22, 生成器Loss:4.25
# 第86周期，第100/600撮, 分类器Loss:0.20, 生成器Loss:4.32
# 第86周期，第200/600撮, 分类器Loss:0.34, 生成器Loss:4.85
# 第86周期，第300/600撮, 分类器Loss:0.16, 生成器Loss:4.62
# 第86周期，第400/600撮, 分类器Loss:0.15, 生成器Loss:4.41
# 第86周期，第500/600撮, 分类器Loss:0.13, 生成器Loss:4.62
# 第87周期，第0/600撮, 分类器Loss:0.20, 生成器Loss:4.06
# 第87周期，第100/600撮, 分类器Loss:0.14, 生成器Loss:4.33
# 第87周期，第200/600撮, 分类器Loss:0.22, 生成器Loss:4.35
# 第87周期，第300/600撮, 分类器Loss:0.23, 生成器Loss:4.58
# 第87周期，第400/600撮, 分类器Loss:0.27, 生成器Loss:4.73
# 第87周期，第500/600撮, 分类器Loss:0.17, 生成器Loss:4.42
# 第88周期，第0/600撮, 分类器Loss:0.23, 生成器Loss:4.49
# 第88周期，第100/600撮, 分类器Loss:0.18, 生成器Loss:4.61
# 第88周期，第200/600撮, 分类器Loss:0.19, 生成器Loss:4.21
# 第88周期，第300/600撮, 分类器Loss:0.17, 生成器Loss:4.32
# 第88周期，第400/600撮, 分类器Loss:0.08, 生成器Loss:4.40
# 第88周期，第500/600撮, 分类器Loss:0.18, 生成器Loss:4.09
# 第89周期，第0/600撮, 分类器Loss:0.26, 生成器Loss:4.30
# 第89周期，第100/600撮, 分类器Loss:0.18, 生成器Loss:4.38
# 第89周期，第200/600撮, 分类器Loss:0.14, 生成器Loss:4.27
# 第89周期，第300/600撮, 分类器Loss:0.15, 生成器Loss:4.37
# 第89周期，第400/600撮, 分类器Loss:0.14, 生成器Loss:4.65
# 第89周期，第500/600撮, 分类器Loss:0.17, 生成器Loss:4.40
# 第90周期，第0/600撮, 分类器Loss:0.26, 生成器Loss:4.38
# 第90周期，第100/600撮, 分类器Loss:0.21, 生成器Loss:4.40
# 第90周期，第200/600撮, 分类器Loss:0.20, 生成器Loss:4.58
# 第90周期，第300/600撮, 分类器Loss:0.19, 生成器Loss:4.38
# 第90周期，第400/600撮, 分类器Loss:0.16, 生成器Loss:4.56
# 第90周期，第500/600撮, 分类器Loss:0.21, 生成器Loss:4.49
# 第91周期，第0/600撮, 分类器Loss:0.17, 生成器Loss:4.29
# 第91周期，第100/600撮, 分类器Loss:0.22, 生成器Loss:4.66
# 第91周期，第200/600撮, 分类器Loss:0.20, 生成器Loss:3.97
# 第91周期，第300/600撮, 分类器Loss:0.16, 生成器Loss:4.52
# 第91周期，第400/600撮, 分类器Loss:0.15, 生成器Loss:4.70
# 第91周期，第500/600撮, 分类器Loss:0.17, 生成器Loss:4.59
# 第92周期，第0/600撮, 分类器Loss:0.12, 生成器Loss:4.37
# 第92周期，第100/600撮, 分类器Loss:0.30, 生成器Loss:4.48
# 第92周期，第200/600撮, 分类器Loss:0.20, 生成器Loss:4.32
# 第92周期，第300/600撮, 分类器Loss:0.14, 生成器Loss:4.19
# 第92周期，第400/600撮, 分类器Loss:0.20, 生成器Loss:4.76
# 第92周期，第500/600撮, 分类器Loss:0.14, 生成器Loss:5.08
# 第93周期，第0/600撮, 分类器Loss:0.19, 生成器Loss:4.32
# 第93周期，第100/600撮, 分类器Loss:0.20, 生成器Loss:4.78
# 第93周期，第200/600撮, 分类器Loss:0.17, 生成器Loss:5.00
# 第93周期，第300/600撮, 分类器Loss:0.16, 生成器Loss:4.24
# 第93周期，第400/600撮, 分类器Loss:0.27, 生成器Loss:4.12
# 第93周期，第500/600撮, 分类器Loss:0.10, 生成器Loss:4.68
# 第94周期，第0/600撮, 分类器Loss:0.18, 生成器Loss:4.10
# 第94周期，第100/600撮, 分类器Loss:0.19, 生成器Loss:4.38
# 第94周期，第200/600撮, 分类器Loss:0.19, 生成器Loss:4.50
# 第94周期，第300/600撮, 分类器Loss:0.19, 生成器Loss:4.52
# 第94周期，第400/600撮, 分类器Loss:0.14, 生成器Loss:4.57
# 第94周期，第500/600撮, 分类器Loss:0.11, 生成器Loss:4.84
# 第95周期，第0/600撮, 分类器Loss:0.19, 生成器Loss:4.54
# 第95周期，第100/600撮, 分类器Loss:0.19, 生成器Loss:4.37
# 第95周期，第200/600撮, 分类器Loss:0.26, 生成器Loss:4.20
# 第95周期，第300/600撮, 分类器Loss:0.14, 生成器Loss:4.60
# 第95周期，第400/600撮, 分类器Loss:0.18, 生成器Loss:4.84
# 第95周期，第500/600撮, 分类器Loss:0.12, 生成器Loss:4.68
# 第96周期，第0/600撮, 分类器Loss:0.18, 生成器Loss:4.45
# 第96周期，第100/600撮, 分类器Loss:0.22, 生成器Loss:4.54
# 第96周期，第200/600撮, 分类器Loss:0.20, 生成器Loss:3.70
# 第96周期，第300/600撮, 分类器Loss:0.19, 生成器Loss:4.72
# 第96周期，第400/600撮, 分类器Loss:0.11, 生成器Loss:4.57
# 第96周期，第500/600撮, 分类器Loss:0.15, 生成器Loss:4.12
# 第97周期，第0/600撮, 分类器Loss:0.11, 生成器Loss:5.19
# 第97周期，第100/600撮, 分类器Loss:0.19, 生成器Loss:4.37
# 第97周期，第200/600撮, 分类器Loss:0.17, 生成器Loss:4.60
# 第97周期，第300/600撮, 分类器Loss:0.22, 生成器Loss:4.30
# 第97周期，第400/600撮, 分类器Loss:0.24, 生成器Loss:5.11
# 第97周期，第500/600撮, 分类器Loss:0.22, 生成器Loss:4.55
# 第98周期，第0/600撮, 分类器Loss:0.19, 生成器Loss:4.35
# 第98周期，第100/600撮, 分类器Loss:0.19, 生成器Loss:4.18
# 第98周期，第200/600撮, 分类器Loss:0.15, 生成器Loss:4.55
# 第98周期，第300/600撮, 分类器Loss:0.26, 生成器Loss:4.45
# 第98周期，第400/600撮, 分类器Loss:0.31, 生成器Loss:4.90
# 第98周期，第500/600撮, 分类器Loss:0.14, 生成器Loss:4.54
# 第99周期，第0/600撮, 分类器Loss:0.17, 生成器Loss:4.05
# 第99周期，第100/600撮, 分类器Loss:0.15, 生成器Loss:5.46
# 第99周期，第200/600撮, 分类器Loss:0.21, 生成器Loss:5.06
# 第99周期，第300/600撮, 分类器Loss:0.11, 生成器Loss:4.64
# 第99周期，第400/600撮, 分类器Loss:0.15, 生成器Loss:4.41
# 第99周期，第500/600撮, 分类器Loss:0.27, 生成器Loss:4.42

# %%
# 预测曲线
plt.figure(figsize = (10, 7))
plt.plot([i[1] for i in results], '.', label = 'Generator', alpha = 0.5)
plt.plot([i[0] for i in results], '.', label = 'Discreminator', alpha = 0.5)
plt.xlabel('Step')
plt.ylabel('Loss')
plt.legend()

# %%
# 绘制一些样本
# fixed_noise = torch.from_numpy(np.random.choice(n_class-1, batch_size))
# fixed_noise = fixed_noise.type(torch.FloatTensor)
# fixed_noise = fixed_noise.unsqueeze(1).expand(fixed_noise.size()[0], input_dim)
# fixed_noise = Variable(fixed_noise)
# fixed_noise.data.resize_(fixed_noise.data.size()[0], input_dim, 1, 1)
# fixed_noise.data = fixed_noise.data.cuda() if use_cuda else fixed_noise.data #gpu transform

fixed_noise = Variable(gen_noise(ys))
fixed_noise.data = fixed_noise.data.cuda() if use_cuda else noise.data #gpu transform
fixed_labels = torch.max(fixed_noise, 1)[1]
fixed_labels = fixed_labels.resize(batch_size)

fake_u = netG(fixed_noise)
fake_u = fake_u.cpu() if use_cuda else fake_u
img = fake_u #.expand(sample_size, 3, image_size, image_size) #将张量转化成可绘制的图像
#print(img.size())
fig = plt.figure(figsize = (15, 15))

sample_size = batch_size
for i in range(sample_size):
    ax = plt.subplot(10, 10, i+1 if i+1 <= 100 else 100)
    ax.axis('off')
    thislabel = fixed_labels[i].cpu().data.numpy()[0] if use_cuda else fixed_labels[i].data.numpy()[0]
    imshow(img[i].data, thislabel)

# %% [markdown]
# ### 方案 2: GAN(2 分类) + CNN(10 分类)
